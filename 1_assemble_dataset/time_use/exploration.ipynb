# %%
import pandas as pd
import numpy as np

# %%
adult_aggregate = pd.read_csv("raw/MTUS-adult-aggregate.csv", low_memory = False)
adult_episode = pd.read_csv("raw/MTUS-adult-episode.csv", low_memory = False)
child_aggregate = pd.read_csv("raw/MTUS-child-aggregate.csv", low_memory = False)
child_episode = pd.read_csv("raw/MTUS-child-episode.csv", low_memory = False)
simple = pd.read_csv("raw/MTUS-simple.csv", low_memory = False)

# %%
simple
# Out:
#         countrya  survey  msamp            hldid          persid  id  day  \
# 0              2    1974      0                0            1001   1    2
# 1              2    1974      0                0            1002   1    6
# 2              2    1974      0                0            1003   1    5
# 3              2    1974      0                0            1004   1    4
# 4              2    1974      0                0            1005   1    3
# ...          ...     ...    ...              ...             ...  ..  ...
# 810603        38    2003      0  999990398540913  20080201081828   1    5
# 810604        38    2003      0  999990398540913  20081009081775   1    6
# 810605        38    2003      0  999990642340652  20031009032141   1    6
# 810606        38    2003      0  999990642340730  20101211102233   1    4
# 810607        38    2003      0  999990668870952  20060605061485   1    5
#
#         month  year  hhldsize  ...  compint  goout  leisure  missing  restrnt  \
# ...

# %%
adult_aggregate
# Out:
#         countrya  survey  swave  msamp            hldid          persid  id  \
# 0              2    1974      0      0                0            1001   1
# 1              2    1974      0      0                0            1002   1
# 2              2    1974      0      0                0            1003   1
# 3              2    1974      0      0                0            1004   1
# 4              2    1974      0      0                0            1005   1
# ...          ...     ...    ...    ...              ...             ...  ..
# 513922        38    2003      0      0  999990398540913  20080201081828   1
# 513923        38    2003      0      0  999990398540913  20081009081775   1
# 513924        38    2003      0      0  999990642340652  20031009032141   1
# 513925        38    2003      0      0  999990642340730  20101211102233   1
# 513926        38    2003      0      0  999990668870952  20060605061485   1
#
# ...

# %%
adult_episode
# Out:
#           countrya  survey  swave  msamp            hldid          persid  id  \
# 0                2    1974      0      0                0            1001   1
# 1                2    1974      0      0                0            1001   1
# 2                2    1974      0      0                0            1001   1
# 3                2    1974      0      0                0            1001   1
# 4                2    1974      0      0                0            1001   1
# ...            ...     ...    ...    ...              ...             ...  ..
# 11501216        38    2003      0      0  999990668870952  20060605061485   1
# 11501217        38    2003      0      0  999990668870952  20060605061485   1
# 11501218        38    2003      0      0  999990668870952  20060605061485   1
# 11501219        38    2003      0      0  999990668870952  20060605061485   1
# 11501220        38    2003      0      0  999990668870952  20060605061485   1
#
# ...

# %%
import os

# %%
os.getlogin()
# Out:
# 'ruixueli'

# %%
os.uname()[0]
# Out:
# 'Darwin'
