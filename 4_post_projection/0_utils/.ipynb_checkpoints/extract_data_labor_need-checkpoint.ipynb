# %%
import xarray as xr
import os
import pandas as pd

def open_dscim_econ_vars(ssp_in, model_in, year_list, econ_vars, 
path_in='/project/cil/gcp/integration/float32/dscim_input_data/econvars/zarrs/integration-econ-bc39.zarr'):

    econ_var_data = xr.open_zarr(path_in)
    
    econ_var_out = (econ_var_data[econ_vars].sel(ssp = ssp_in, model = model_in, year = year_list).to_dataframe()) 
                    
    econ_var_out.reset_index(inplace = True)
                    
    return econ_var_out

# %%
df = open_dscim_econ_vars(
    ssp_in="SSP3",
    model_in="IIASA GDP",
    year_list=[2015],            # list of ints
    econ_vars=["gdp", "gdppc","pop"],
    path_in="/project/cil/gcp/integration/float32/dscim_input_data/econvars/zarrs/integration-econ-bc39.zarr",
)
df.head()
# Out:
#                     region  year          gdp        gdppc            pop  \
# 0                      ABW  2015  256953808.0  2198.738037  116864.218750
# 1                 AFG.1.12  2015   32536026.0  1578.548584   20611.355469
# 2  AFG.1.R8abddb145b8788ee  2015  710071552.0  1578.572266  449818.843750
# 3  AFG.1.R91a8634efe8e02a7  2015  229704288.0  1578.563599  145514.750000
# 4  AFG.1.Ra6a2bba0a271cb4a  2015  853774464.0  1579.352905  540585.000000
#
#        model   ssp
# 0  IIASA GDP  SSP3
# 1  IIASA GDP  SSP3
# 2  IIASA GDP  SSP3
# 3  IIASA GDP  SSP3
# 4  IIASA GDP  SSP3

# %%
df.to_csv('/project/cil/battuta_shares/gcp/estimation/labor/code_release_int_data/projection_outputs/covariates/econ_vars2015.csv', index=False)
